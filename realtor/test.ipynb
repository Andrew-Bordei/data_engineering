# %%
import requests
import json

# %%
payload = "{\"query\":\"query ConsumerSearchQuery($query: HomeSearchCriteria!, $limit: Int, $offset: Int, $search_promotion: SearchPromotionInput, $sort: [SearchAPISort], $sort_type: SearchSortType, $client_data: JSON, $bucket: SearchAPIBucket, $mortgage_params: MortgageParamsInput, $photosLimit: Int) {\\n  home_search: home_search(\\n    query: $query\\n    sort: $sort\\n    limit: $limit\\n    offset: $offset\\n    sort_type: $sort_type\\n    client_data: $client_data\\n    bucket: $bucket\\n    search_promotion: $search_promotion\\n    mortgage_params: $mortgage_params\\n  ) {\\n    count\\n    total\\n    search_promotion {\\n      names\\n      slots\\n      promoted_properties {\\n        id\\n        from_other_page\\n        __typename\\n      }\\n      __typename\\n    }\\n    mortgage_params {\\n      interest_rate\\n      __typename\\n    }\\n    properties: results {\\n      property_id\\n      list_price\\n      rmn_listing_attribution\\n      search_promotions {\\n        name\\n        asset_id\\n        __typename\\n      }\\n      primary_photo(https: true) {\\n        href\\n        __typename\\n      }\\n      listing_id\\n      matterport\\n      virtual_tours {\\n        href\\n        type\\n        __typename\\n      }\\n      status\\n      products {\\n        products\\n        brand_name\\n        __typename\\n      }\\n      source {\\n        id\\n        name\\n        type\\n        spec_id\\n        plan_id\\n        agents {\\n          office_name\\n          __typename\\n        }\\n        listing_id\\n        __typename\\n      }\\n      lead_attributes {\\n        show_contact_an_agent\\n        market_type\\n        opcity_lead_attributes {\\n          cashback_enabled\\n          flip_the_market_enabled\\n          __typename\\n        }\\n        lead_type\\n        ready_connect_mortgage {\\n          show_contact_a_lender\\n          show_veterans_united\\n          __typename\\n        }\\n        __typename\\n      }\\n      community {\\n        description {\\n          name\\n          __typename\\n        }\\n        property_id\\n        permalink\\n        advertisers {\\n          office {\\n            hours\\n            phones {\\n              type\\n              number\\n              primary\\n              trackable\\n              __typename\\n            }\\n            __typename\\n          }\\n          __typename\\n        }\\n        promotions {\\n          description\\n          href\\n          headline\\n          promotion_type\\n          __typename\\n        }\\n        __typename\\n      }\\n      permalink\\n      price_reduced_amount\\n      description {\\n        name\\n        beds\\n        baths_consolidated\\n        sqft\\n        lot_sqft\\n        baths_max\\n        baths_min\\n        beds_min\\n        beds_max\\n        sqft_min\\n        sqft_max\\n        type\\n        sub_type\\n        sold_price\\n        sold_date\\n        year_built\\n        garage\\n        __typename\\n      }\\n      location {\\n        street_view_url\\n        address {\\n          line\\n          postal_code\\n          state\\n          state_code\\n          city\\n          coordinate {\\n            lat\\n            lon\\n            __typename\\n          }\\n          __typename\\n        }\\n        county {\\n          name\\n          fips_code\\n          __typename\\n        }\\n        __typename\\n      }\\n      open_houses {\\n        start_date\\n        end_date\\n        __typename\\n      }\\n      branding {\\n        type\\n        name\\n        photo\\n        __typename\\n      }\\n      flags {\\n        is_coming_soon\\n        is_new_listing(days: 14)\\n        is_price_reduced(days: 30)\\n        is_foreclosure\\n        is_new_construction\\n        is_pending\\n        is_contingent\\n        __typename\\n      }\\n      list_date\\n      photos(limit: $photosLimit, https: true) {\\n        href\\n        __typename\\n      }\\n      advertisers {\\n        type\\n        fulfillment_id\\n        name\\n        builder {\\n          name\\n          href\\n          logo\\n          fulfillment_id\\n          __typename\\n        }\\n        email\\n        office {\\n          name\\n          __typename\\n        }\\n        phones {\\n          number\\n          __typename\\n        }\\n        __typename\\n      }\\n      consumer_advertisers {\\n        type\\n        agent_id\\n        name\\n        __typename\\n      }\\n      last_status_change_date\\n      last_price_change_amount\\n      __typename\\n    }\\n    __typename\\n  }\\n  commute_polygon: get_commute_polygon(query: $query) {\\n    areas {\\n      id\\n      breakpoints {\\n        width\\n        height\\n        zoom\\n        __typename\\n      }\\n      radius\\n      center {\\n        lat\\n        lng\\n        __typename\\n      }\\n      __typename\\n    }\\n    boundary\\n    __typename\\n  }\\n}\",\"variables\":{\"photosLimit\":3,\"query\":{\"primary\":true,\"status\":[\"for_sale\",\"ready_to_build\"],\"search_location\":{\"location\":\"Boise, ID\"}},\"client_data\":{\"device_data\":{\"device_type\":\"mobile\"}},\"limit\":42,\"offset\":42,\"sort_type\":\"relevant\",\"bucket\":{\"sort\":\"fractal_v6.5.0\"},\"search_promotion\":{\"names\":[\"CITY\",\"POSTALCODECITY\"],\"slots\":[],\"promoted_properties\":[[]]}}}"

# %%
url = "https://www.realtor.com/frontdoor/graphql"

headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:142.0) Gecko/20100101 Firefox/142.0',
  'Accept': '*/*',
  'Accept-Language': 'en-US,en;q=0.5',
  'Accept-Encoding': 'gzip, deflate, br, zstd',
  'Referer': 'https://www.realtor.com/realestateandhomes-search/Boise_ID/pg-2',
  'content-type': 'application/json',
  'rdc-client-name': 'RDC_WEB_SRP_FS_PAGE',
  'rdc-client-version': '3.0.2247',
  'x-is-bot': 'false',
  'x-rdc-visitor-id': 'fb80ae97-a551-485b-9035-180f85484599',
  'srp-consumer-triggered-request': 'rdc-search-for-sale',
  'Origin': 'https://www.realtor.com',
  'Alt-Used': 'www.realtor.com',
  'Connection': 'keep-alive',
  'Cookie': 'split=n; split_tcv=180; __vst=fb80ae97-a551-485b-9035-180f85484599; __bot=false; s_ecid=MCMID%7C36875384715995806410199041729572697991; AMCV_8853394255142B6A0A4C98A4%40AdobeOrg=-1124106680%7CMCMID%7C36875384715995806410199041729572697991%7CMCIDTS%7C20344%7CMCAID%7CNONE%7CMCOPTOUT-1757800628s%7CNONE%7CvVersion%7C5.2.0; _lr_env_src_ats=false; __split=36; __rdc_id=rdc-id-f7752523-620f-42de-9af8-95a8b2f64a2b; ajs_anonymous_id=e5ad916a-ba8f-48ed-a6fc-c04a31a5284b; G_ENABLED_IDPS=google; _parsely_visitor={%22id%22:%22pid=8f78c9b4-be78-42b7-888d-05c96a3b6406%22%2C%22session_count%22:2%2C%22last_session_ts%22:1757793404081}; __ssn=1d412847-e9eb-465c-84b1-9dedf1172967; __ssnstarttime=1757000912; AMCVS_8853394255142B6A0A4C98A4%40AdobeOrg=1; srchID=4355a5fe3cdb4829bb2db93f26f1684a; criteria=sprefix%3D%252Fnewhomecommunities%26area_type%3Dcity%26city%3DBoise%26pg%3D1%26state_code%3DID%26state_id%3DID%26loc%3DBoise%252C%2520ID%26locSlug%3DBoise_ID%26county_fips%3D16001%26county_fips_multi%3D16001; KP_UIDz-ssn=0Ul9EcpfnUh7hdaNhrkTkiO2wcFPtBlfXRNZQwIfpVqOyaNMJVBE3Qgt7FmMqy2qz5i7fwaKerFLtWpK19CfOE8ssMngfVcBr1QKmXCP6Ppe1NiafKLuGhojogroJIiGUBpHGOLhRh7CtnmWXLwyyIVYjZdXA5qlKqbhbYZ1zCiICugr; KP_UIDz=0Ul9EcpfnUh7hdaNhrkTkiO2wcFPtBlfXRNZQwIfpVqOyaNMJVBE3Qgt7FmMqy2qz5i7fwaKerFLtWpK19CfOE8ssMngfVcBr1QKmXCP6Ppe1NiafKLuGhojogroJIiGUBpHGOLhRh7CtnmWXLwyyIVYjZdXA5qlKqbhbYZ1zCiICugr; _lr_retry_request=true; _parsely_session={%22sid%22:2%2C%22surl%22:%22https://www.realtor.com/realestateandhomes-search/Arkansas%22%2C%22sref%22:%22https://www.realtor.com/%22%2C%22sts%22:1757793404081%2C%22slts%22:1757696617932}; _parsely_slot_click={%22url%22:%22https://www.realtor.com/realestateandhomes-search/Boise_ID%22%2C%22x%22:270%2C%22y%22:21437%2C%22xpath%22:%22//*[@id=%5C%22__next%5C%22]/div[1]/div[4]/div[6]/div[1]/div[1]/a[1]%22%2C%22href%22:%22https://www.realtor.com/realestateandhomes-search/Boise_ID/pg-2%22}; __bot=false; __vst=8a957e7d-82d6-44bc-83e1-296f9069dff9; split=n; split_tcv=117',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'Sec-GPC': '1',
  'Priority': 'u=4',
  'TE': 'trailers'
}

# %%
response = requests.request("POST", url, headers=headers, data=payload)

# %%
print(response.text)
# Out:
# {"data":{"home_search":{"count":42,"total":1585,"search_promotion":{"names":["CITY","POSTALCODECITY"],"slots":[],"promoted_properties":[[],[]],"__typename":"SearchPromotionNextPagePayload"},"mortgage_params":{"interest_rate":6.239,"__typename":"MortgageParams"},"properties":[{"property_id":"2226183231","list_price":346400,"rmn_listing_attribution":false,"search_promotions":null,"primary_photo":{"href":"https://ap.rdcpix.com/8bec0cdb8436759f9195eb150765e1cal-m1433032184s.jpg","__typename":"HomePhoto"},"listing_id":"2986154094","matterport":false,"virtual_tours":[{"href":"https://www.tourfactory.com/idxr3194879","type":null,"__typename":"VirtualTour"}],"status":"for_sale","products":{"products":["core.agent","core.broker","co_broke"],"brand_name":"essentials","__typename":"ProductSummarySearchHome"},"source":{"id":"BOID","name":"IntermountainMLS","type":"mls","spec_id":null,"plan_id":null,"agents":[{"office_name":null,"__typename":"MlsAgent"},{"office_name":null,"__typename":"MlsAgent"}],"listing_id":"98960934","__typename":"MlsSource"},"lead_attributes":{"show_contact_an_agent":true,"market_type":"pure","opcity_lead_attributes":{"cashback_enabled":false,"flip_the_market_enabled":true,"__typename":"OpCityLeadAttributes"},"lead_type":"co_broke","ready_connect_mortgage":{"show_contact_a_lender":false,"show_veterans_united":false,"__typename":"ReadyConnectMortgage"},"__typename":"LeadAttributes"},"community":null,"permalink":"3063-S-Cantrell-Ln_Boise_ID_83706_M22261-83231","price_reduced_amount":3500,"description":{"name":null,"beds":2,"baths_consolidated":"2","sqft":1105,"lot_sqft":1307,"baths_max":null,"baths_min":null,"beds_min":null,"beds_max":null,"sqft_min":null,"sqft_max":null,"type":"multi_family","sub_type":null,"sold_price":null,"sold_date":"2022-11-03","year_built":1983,"garage":1,"__typename":"SearchHomeDescription"},"location":{"street_view_url":"https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=3063%20S%20Cantrell%20Ln%2C%20Boise%2C%20ID%2083706&size=640x480&source=outdoor&signature=s7T8tMpT9lj1Vgm0-3vkJaIzRZQ=","address":{"line":"3063 S Cantrell Ln","postal_code":"83706","state":"Idaho","state_code":"ID","city":"Boise","coordinate":{"lat":43.574607,"lon":-116.161798,"__typename":"Coordinate"},"__typename":"SearchHomeAddress"},"county":{"name":"Ada","fips_code":"16001","__typename":"HomeCounty"},"__typename":"SearchHomeLocation"},"open_houses":[{"start_date":"2025-09-13T14:00:00","end_date":"2025-09-13T16:00:00","__typename":"HomeOpenHouse"}],"branding":[{"type":"Office","name":"Silvercreek Realty Group","photo":null,"__typename":"Branding"}],"flags":{"is_coming_soon":null,"is_new_listing":true,"is_price_reduced":true,"is_foreclosure":null,"is_new_construction":null,"is_pending":null,"is_contingent":null,"__typename":"SearchHomeFlags"},"list_date":"2025-09-08T19:08:37.000000Z","photos":[{"href":"https://ap.rdcpix.com/8bec0cdb8436759f9195eb150765e1cal-m1433032184s.jpg","__typename":"HomePhoto"},{"href":"https://ap.rdcpix.com/8bec0cdb8436759f9195eb150765e1cal-m1543901295s.jpg","__typename":"HomePhoto"},{"href":"https://ap.rdcpix.com/8bec0cdb8436759f9195eb150765e1cal-m578117334s.jpg","__typename":"HomePhoto"}],"advertisers":[{"type":"seller","fulfillment_id":"4356289","name":"Jill  Ashby","builder":null,"email":"Jill@recounselor.com","office":{"name":"Silvercreek Realty Group","__typename":"HomeAdvertiserOffice"},"phones":[{"number":"2087030744","__typename":"AdvertiserPhone"}],"__typename":"HomeAdvertiser"},{"type":"co_seller","fulfillment_id":"3045786","name":"Christian Busnardo","builder":null,"email":"christian@recounselor.com","office":{"name":"Silvercreek Realty Group","__typename":"HomeAdvertiserOffice"},"phones":[{"number":"2088803705","__typename":"AdvertiserPhone"}],"__typename":"HomeAdvertiser"}],"consumer_advertisers":null,"last_status_change_date":"2025-09-08T19:08:37Z","last_price_change_amount":-3500,"__typename":"SearchHome"},{"property_id":"2108418481 ...

# %%
data = json.loads(response.text)

# %%
num_houses = data['data']['home_search']['count']

# %%
base_path = data['data']['home_search']['properties']

# %%
property_id = base_path[0]['property_id']

# %%
list_price = base_path[0]['list_price']

# %%
listing_id = base_path[0]['listing_id']

# %%
beds = base_path[0]['description']['beds']

# %%
baths_consolidated = base_path[0]['description']['baths_consolidated']

# %%
sqft = base_path[0]['description']['sqft']

# %%
lot_sqft = base_path[0]['description']['lot_sqft']

# %%
year_built = base_path[0]['description']['year_built']

# %%
garage_num = base_path[0]['description']['garage']

# %%
address_line = base_path[0]['location']['address']['line']

# %%
postal_code = base_path[0]['location']['address']['postal_code']

# %%
state_code = base_path[0]['location']['address']['state_code']

# %%
city = base_path[0]['location']['address']['city']

# %%
last_price_change_amount = base_path[0]['last_price_change_amount']
last_price_change_amount
# Out:
# -3500

# %%
house_data = {
    property_id, 
    list_price, 
    listing_id, 
    beds,
    baths_consolidated,  
    sqft, 
    lot_sqft, 
    year_built, 
    garage_num, 
    address_line, 
    postal_code,
    state_code, 
    city, 
    last_price_change_amount,

}
